# %%
print('Assalamualaikum Wr Wb')
# Out:
# Assalamualaikum Wr Wb

# %%
print('Nama = Yulia Dwi Ferdiani')
print('NIM  = 200601110105')
# Out:
# Nama = Yulia Dwi Ferdiani
# NIM  = 200601110105

# %%
a=12345
type(a)
# Out:
# int

# %%
b=str(a)
b
# Out:
# '12345'

# %%
type(b)
# Out:
# str

# %%
print('Coba Algorithm 2.1 str( )')
# Out:
# Coba Algorithm 2.1 str( )

# %%
'-------------------------------------------------------------------'
# Out:
# '-------------------------------------------------------------------'

# %%
a='12345'
type(a)
# Out:
# str

# %%
b=int(a)
b
# Out:
# 12345

# %%
type(b)
# Out:
# int

# %%
print('Coba Algorithm 2.2 int( )')
# Out:
# Coba Algorithm 2.2 int( )

# %%
'------------------------------------------------------------------'
# Out:
# '------------------------------------------------------------------'

# %%
 int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
a=True
type(a)
# Out:
# bool

# %%
int(a)
# Out:
# 1

# %%
print('Coba Algorithm 2.3')
# Out:
# Coba Algorithm 2.3

# %%
'-------------------------------------------------------------------'
# Out:
# '-------------------------------------------------------------------'

# %%
a=123.456
a
# Out:
# 123.456

# %%
type(a)
# Out:
# float

# %%
a*2
# Out:
# 246.912

# %%
print('Coba Algorithm 2.4')
# Out:
# Coba Algorithm 2.4

# %%
'----------------------------------------------------------------------'
# Out:
# '----------------------------------------------------------------------'

# %%
a=8.9e-4
a
# Out:
# 0.00089

# %%
print('Coba Algorithm 2.5')
# Out:
# Coba Algorithm 2.5

# %%
'---------------------------------------------------------------------'
# Out:
# '---------------------------------------------------------------------'

# %%
a=123.456
type(a)
# Out:
# float

# %%
b=str(a)
b
# Out:
# '123.456'

# %%
type(b)
# Out:
# str

# %%
c=float(b)
c
# Out:
# 123.456

# %%
type(c)
# Out:
# float

# %%
print('Algorithm 2.6')
# Out:
# Algorithm 2.6

# %%
'-------------------------------------------------------------------'
# Out:
# '-------------------------------------------------------------------'

# %%
a=-9+17j
a
# Out:
# (-9+17j)

# %%
type(a)
# Out:
# complex

# %%
a.real
# Out:
# -9.0

# %%
a.imag
# Out:
# 17.0

# %%
print('Coba Algorithm 2.7')
# Out:
# Coba Algorithm 2.7

# %%
'------------------------------------------------------------------'
# Out:
# '------------------------------------------------------------------'

# %%
s1='PyQt'
s1
# Out:
# 'PyQt'

# %%
s2="Python"
s2
# Out:
# 'Python'

# %%
s3='''Pemrograman GUI dengan Python dan PyQt'''
s3
# Out:
# 'Pemrograman GUI dengan Python dan PyQt'

# %%
s4="""Pemrograman GUI dengan Python dan PyQt"""
s4
# Out:
# 'Pemrograman GUI dengan Python dan PyQt'

# %%
b='Python'
b
# Out:
# 'Python'

# %%
b=b.capitalize( )
b
# Out:
# 'Python'

# %%
b=b.upper()
b
# Out:
# 'PYTHON'

# %%
b=b.lower()
b
# Out:
# 'python'

# %%
b.isupper()
# Out:
# False

# %%
b.islower()
# Out:
# True

# %%
s=' '.join(['saya','makan','ayam'])
s
# Out:
# 'saya makan ayam'

# %%
nim='200601110105'
nim.isnumeric()
# Out:
# True

# %%
nim='2006011101o5'
nim.isnumeric()
# Out:
# False

# %%
print('Coba Algorithm 2.8')
# Out:
# Coba Algorithm 2.8

# %%
'------------------------------------------------------------------------'
# Out:
# '------------------------------------------------------------------------'
